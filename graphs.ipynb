# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read data from CSV
flags = ["O0"]
sizes = ["small","med","big"]
elem_num = { "small": 100 , "med" : 2500, "big": 5000}
# Extract relevant columns


data_path = f"measurementsGlobal.csv"
data = pd.read_csv(data_path)
programs = data['Program']
powerlimit = data['PowerLimit']
powerconsumed = data['Package']
time = data['Time']
memory = data['Memory']
# Create DataFrame
df = pd.DataFrame({'Program': programs, 'PowerLimit': powerlimit, 'Energy Comsumption': powerconsumed})
# Calculate mean time and memory for each power limit
#mean_data = df.groupby(['Program','PowerLimit']).mean()
# Plot
#mean_data.plot(kind='bar', figsize=(10, 6))
plt.figure(figsize=(20, 6))

sns.barplot(data=df, x='Program', y='Energy Comsumption', hue='PowerLimit')
plt.title(f"Runtime of Each Algorithm Sorted")
plt.xlabel('Power Limit')
plt.ylabel('Runtime (ms)')
plt.grid(axis='y')
plt.legend(title='Algorithm')
#plt.savefig(f"images/runtime{flag}{size}Sorted.png")
plt.show()
